# %%
'''

Inspiration
The idea is to see if we can use this dataset to

1) Visualize the water need / usage of the city
2) Identify whether the water sources availability will be able to meet the needs till the subsequent monsoon?
3) How bad is the current water crisis compared to previous years?

Datasets from
https://www.kaggle.com/sudalairajkumar/chennai-water-management

'''

reservoir_csv = "..\\..\\..\\Data\\GW\\chennai-water-management\\chennai_reservoir_levels.csv"
rainfall_csv = "..\\..\\..\\Data\\GW\\chennai-water-management\\chennai_reservoir_rainfall.csv"

import pandas as pd
from pandas import DataFrame as df

reservoir_df = pd.read_csv(reservoir_csv)
rainfall_df =  pd.read_csv(rainfall_csv)
reservoir_df.head()
# Out:
#          Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0  01-01-2004     3.9         0.0     268.0              0.0
# 1  02-01-2004     3.9         0.0     268.0              0.0
# 2  03-01-2004     3.9         0.0     267.0              0.0
# 3  04-01-2004     3.9         0.0     267.0              0.0
# 4  05-01-2004     3.8         0.0     267.0              0.0

# %%
rainfall_df.head()
# Out:
#          Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0  01-01-2004     0.0         0.0       0.0              0.0
# 1  02-01-2004     0.0         0.0       0.0              0.0
# 2  03-01-2004     0.0         0.0       0.0              0.0
# 3  04-01-2004     0.0         0.0       0.0              0.0
# 4  05-01-2004     0.0         0.0       0.0              0.0

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(reservoir_df["Date"].count())

y = np.zeros((len(x),4))

for r in range(len(x)):
    for c in range( reservoir_df.shape[1]-1):
        y[r][c] = reservoir_df.iloc[r,c+1]
    
plt.clf()
plt.plot(x,y)

list = reservoir_df.columns.values.tolist()
#plt.yticks(np.arange(len(list)*10),list )
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(rainfall_df["Date"].count())
y = np.zeros((len(x),4))

for r in range(len(x)):
    for c in range( rainfall_df.shape[1]-1):
        y[r][c] = rainfall_df.iloc[r,c+1]
    
plt.clf()
plt.plot(x,y)

list = rainfall_df.columns.values.tolist()
#plt.yticks(np.arange(len(list)),list )
plt.show()

# %%
x = reservoir_df["POONDI"]
y = rainfall_df["POONDI"]

plt.scatter(x,y)
plt.show()

# %%
x = np.arange(reservoir_df["Date"].count())

res = reservoir_df["POONDI"]
rain = rainfall_df["POONDI"]

#print(y)
plt.clf()
plt.plot(x,rain)
plt.plot(x,res)
plt.show()

# %%
x = [0,1,2,3,4,5]
y = [[0,1,2,3,4,5,100],[0,1,2,3,4,5,3],[0,1,2,3,4,5,3],[0,1,2,3,4,5,3],[0,1,2,3,4,5,3],[0,1,2,3,4,5,3]]
plt.figure(1, figsize=(10,10))
plt.clf()
#plt.imshow(panel )
stacktime = 5
receivers = 10
plt.plot(x,y,color='black')
plt.show()
